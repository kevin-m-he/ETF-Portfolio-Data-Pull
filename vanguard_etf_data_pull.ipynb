# %% [markdown]
# # This python script pulls price history for 76 Vanguard ETFs from 2018 to 2022
#
# ### ETFs were manually copied from Vanguard's website https://investor.vanguard.com/etf/list#/etf/asset-class/month-end-returns and placed into vanguard_etfs.csv
#
# ### This script is used with m_portfolio_allocation to generate a markowitz portfolio allocation analysis on Vanguard's ETFs
#
# ### Link to the Tableau Dashboard: https://public.tableau.com/views/All-ETFPortfolioOptimizer/All-ETFPortfolioOptimizer?:language=en-US&:display_count=n&:origin=viz_share_link

# %%
import pandas as pd
import numpy as np
import yfinance as yf

# %%
etfs = pd.read_csv('vanguard_etfs.csv')

# %% [markdown]
# ### Below is the csv that was manually made from Vanguard's website

# %%
etfs
# Out:
#    Ticker                   Asset Class  Expense Ratio   Price     YTD  \
# 0     EDV   Bond - Long-term Government         0.0006  105.93 -0.2395
# 1     BIV  Bond - Inter-term Investment         0.0004   78.52 -0.0991
# 2    VGIT  Bond - Inter-term Government         0.0004   61.28 -0.0754
# 3     BLV   Bond - Long-term Investment         0.0004   82.71 -0.1890
# 4    VGLT   Bond - Long-term Government         0.0004   72.88 -0.1809
# ..    ...                           ...            ...     ...     ...
# 71    VIS                Stock - Sector         0.0010  179.22 -0.1141
# 72    VGT                Stock - Sector         0.0010  367.38 -0.1966
# 73    VAW                Stock - Sector         0.0010  186.16 -0.0512
# 74    VNQ                Stock - Sector         0.0012  103.87 -0.0992
# 75    VPU                Stock - Sector         0.0010  154.69 -0.0043
#
#     1-year annual returns  5-year annual returns  10-year annual returns  \
# 0                 -0.0077                 0.0522                  0.0550
# 1                 -0.0462                 0.0252                  0.0273
# 2                 -0.0495                 0.0152                  0.0159
# 3                 -0.0338                 0.0453                  0.0470
# 4                 -0.0135                 0.0387                  0.0394
# ..                    ...                    ...                     ...
# 71                 0.0406                 0.1120                  0.1273
# 72                 0.1697                 0.2644                  0.2020
# 73                 0.1402                 0.1231                  0.1108
# 74                 0.2142                 0.0967                  0.0969
# 75                 0.1855                 0.1087                  0.1164
#
#     total annual returns ETF Start Date
# 0                 0.0687      12/6/2007
# 1                 0.0439       4/3/2007
# 2                 0.0239     11/19/2009
# 3                 0.0614       4/3/2007
# 4                 0.0525     11/19/2009
# ..                   ...            ...
# 71                0.0996      9/23/2004
# 72                0.1327      1/26/2004
# 73                0.0989      1/26/2004
# 74                0.0926      9/23/2004
# 75                0.1032      1/26/2004
#
# [76 rows x 10 columns]

# %%
tickers = etfs['Ticker']

# %%
def get_price_data(ticker_list):
    list_of_dfs = []
    for i in ticker_list:
        ticker = i

        tickerdata = yf.Ticker(ticker)

        pricedf = tickerdata.history(period='1d',start = '2018-1-1', end = '2022-4-30')

        pricedf = pricedf.drop(columns = ['Dividends','Stock Splits'])
        
        pricedf['Ticker'] = i
        
        pricedf['Date'] = pricedf.index
                                     
        list_of_dfs.append(pricedf)
    return list_of_dfs

# %%
etf_data_list = get_price_data(tickers)

# %%
all_etfs = pd.concat(etf_data_list)

# %% [markdown]
# ### Below is the output from using the tickers and pulling data from yahoo finance from 1/1/2018 to 4/30/2022

# %%
all_etfs
# Out:
#                   Open        High         Low       Close  Volume Ticker  \
# Date
# 2018-01-02  104.346624  104.346624  102.709849  103.238121   86200    EDV
# 2018-01-03  103.619171  103.861655  103.238120  103.688454   38800    EDV
# 2018-01-04  103.471955  103.913620  103.056263  103.870323   33200    EDV
# 2018-01-05  103.489255  103.792360  102.952321  103.385330   45500    EDV
# 2018-01-08  103.679785  103.714427  102.874388  103.168831   48200    EDV
# ...                ...         ...         ...         ...     ...    ...
# 2022-04-25  161.600006  161.779999  157.399994  159.949997  359000    VPU
# 2022-04-26  159.360001  161.250000  158.419998  158.449997  208400    VPU
# 2022-04-27  158.729996  159.889999  157.289993  157.589996  732300    VPU
# 2022-04-28  158.520004  159.929993  157.679993  159.440002  491000    VPU
# 2022-04-29  158.619995  158.860001  154.479996  154.729996  300800    VPU
#
#                  Date
# Date
# 2018-01-02 2018-01-02
# 2018-01-03 2018-01-03
# 2018-01-04 2018-01-04
# 2018-01-05 2018-01-05
# 2018-01-08 2018-01-08
# ...               ...
# 2022-04-25 2022-04-25
# 2022-04-26 2022-04-26
# 2022-04-27 2022-04-27
# 2022-04-28 2022-04-28
# 2022-04-29 2022-04-29
#
# [80800 rows x 7 columns]

# %%
all_etfs.to_csv('etf_price_data.csv',index = False)

# %% [markdown]
# ### Ticker information is also pulled from yahoo finance and placed in a csv

# %%
def get_ticker_info(ticker_list):
    
    list_of_etf_info = []
    for i in ticker_list:
        
        ticker = i

        tickerdata = yf.Ticker(ticker)

        #Get basic ticker info
        tickerinfo = tickerdata.info

        infocols = list(tickerinfo.keys())

        infodf = pd.DataFrame.from_dict(tickerinfo,orient='index')
        
        infodf['Ticker'] = i

        infodf.reset_index(inplace = True)

        infodf['measure'] = infodf['index']
        infodf['value'] = infodf[0]
        infodf = infodf.drop(columns = ['index',0])

        list_of_etf_info.append(infodf)
        
    return list_of_etf_info

# %%
etf_info_list = get_ticker_info(tickers)

# %%
etf_info_list[0]
# Out:
#     Ticker                    measure  \
# 0      EDV                   exchange
# 1      EDV                  shortName
# 2      EDV                   longName
# 3      EDV       exchangeTimezoneName
# 4      EDV  exchangeTimezoneShortName
# ..     ...                        ...
# 98     EDV              dividendYield
# 99     EDV                    bidSize
# 100    EDV                    dayHigh
# 101    EDV         regularMarketPrice
# 102    EDV                   logo_url
#
#                                               value
# 0                                               PCX
# 1                   Vanguard Extended Duration Trea
# 2    Vanguard Extended Duration Treasury Index Fund
# 3                                  America/New_York
# 4                                               EDT
# ..                                              ...
# 98                                             None
# 99                                              900
# 100                                        107.9699
# 101                                          105.84
# 102
#
# [103 rows x 3 columns]

# %%
etf_info_df = pd.concat(etf_info_list)

# %%
etf_info_df.to_csv('etf_info.csv',index = False)
